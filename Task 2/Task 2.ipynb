# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\\Users\\Tokii\\Downloads\\customer_booking.csv",encoding="ISO-8859-1")
data
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   2      Internet  RoundTrip            262              19
# 1                   1      Internet  RoundTrip            112              20
# 2                   2      Internet  RoundTrip            243              22
# 3                   1      Internet  RoundTrip             96              31
# 4                   2      Internet  RoundTrip             68              22
# ...               ...           ...        ...            ...             ...
# 49995               2      Internet  RoundTrip             27               6
# 49996               1      Internet  RoundTrip            111               6
# 49997               1      Internet  RoundTrip             24               6
# 49998               1      Internet  RoundTrip             15               6
# 49999               1      Internet  RoundTrip             19               6
#
# ...

# %%
data["sales_channel"].replace({"Internet":0,"Mobile":1},inplace=True)
data["trip_type"].replace({"RoundTrip":0,"CircleTrip":1,"OneWay":2},inplace=True)
data["flight_day"].replace({"Mon": 1,"Tue": 2,"Wed": 3,"Thu": 4,"Fri": 5,"Sat": 6,"Sun": 7},inplace=True)
data
# Out:
#        num_passengers  sales_channel  trip_type  purchase_lead  \
# 0                   2              0          0            262
# 1                   1              0          0            112
# 2                   2              0          0            243
# 3                   1              0          0             96
# 4                   2              0          0             68
# ...               ...            ...        ...            ...
# 49995               2              0          0             27
# 49996               1              0          0            111
# 49997               1              0          0             24
# 49998               1              0          0             15
# 49999               1              0          0             19
#
#        length_of_stay  flight_hour  flight_day   route booking_origin  \
# 0                  19            7           6  AKLDEL    New Zealand
# ...

# %%
data["route"].value_counts()
# Out:
# AKLKUL    2680
# PENTPE     924
# MELSGN     842
# ICNSIN     801
# DMKKIX     744
#           ...
# LBUTPE       1
# CXRMEL       1
# DELKBR       1
# KOSSYD       1
# MRUXIY       1
# Name: route, Length: 799, dtype: int64

# %%
data["booking_origin"].value_counts()
# Out:
# Australia               17872
# Malaysia                 7174
# South Korea              4559
# Japan                    3885
# China                    3387
#                         ...
# Panama                      1
# Tonga                       1
# Tanzania                    1
# Bulgaria                    1
# Svalbard & Jan Mayen        1
# Name: booking_origin, Length: 104, dtype: int64

# %%
data
# Out:
#        num_passengers  sales_channel  trip_type  purchase_lead  \
# 0                   2              0          0            262
# 1                   1              0          0            112
# 2                   2              0          0            243
# 3                   1              0          0             96
# 4                   2              0          0             68
# ...               ...            ...        ...            ...
# 49995               2              0          0             27
# 49996               1              0          0            111
# 49997               1              0          0             24
# 49998               1              0          0             15
# 49999               1              0          0             19
#
#        length_of_stay  flight_hour  flight_day  wants_extra_baggage  \
# 0                  19            7           6                    1
# 1                  20            3           6                    0
# ...

# %%
data.columns
# Out:
# Index(['num_passengers', 'sales_channel', 'trip_type', 'purchase_lead',
#        'length_of_stay', 'flight_hour', 'flight_day', 'wants_extra_baggage',
#        'wants_preferred_seat', 'wants_in_flight_meals', 'flight_duration',
#        'booking_complete'],
#       dtype='object')

# %%
data.isna().value_counts()
# Out:
# num_passengers  sales_channel  trip_type  purchase_lead  length_of_stay  flight_hour  flight_day  wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  flight_duration  booking_complete
# False           False          False      False          False           False        False       False                False                 False                  False            False               50000
# dtype: int64

# %%
data["booking_complete"].value_counts()
# Out:
# 0    42522
# 1     7478
# Name: booking_complete, dtype: int64

# %%
data.to_csv("D:/filtered_BA")
